# %% [markdown]
# # Final check — geography
# Two task cells exercising two modes.

# %% [markdown]
# ## European capitals — default graded mode (`geo-europe`)
#
# * Write one sentence below explaining which city you picked and why.
# * The instructor grades that sentence manually for 2 points; the auto-grader grades the quiz separately for 4 points.
#
# #### Quiz encoded=false
# * (SC) {3} "What is the capital of France?"
#   + "Paris"
#   - "Berlin"
#   - "Madrid"
# * (NM) "How many official EU member states as of 2024?"
#   + <27>
#
# #### End Quiz
#
# <!-- instructor grades the explanation paragraph here -->

# %% [markdown]
# ## Asian capitals — graded with visible correctness (`geo-asia`)
# Clicking a wrong answer will turn it red; the score is still recorded.
#
# #### Quiz encoded=false hide_correctness=false
# * (SC) "What is the capital of Japan?"
#   + "Tokyo"
#   - "Kyoto"
#   - "Osaka"
#   - "Sapporo"
# #### End Quiz
